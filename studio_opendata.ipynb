# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
import plotly.graph_objects as go
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error,mean_squared_error

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('dati.xlsx',
                    index_col='Calendario',
                    parse_dates=True
                    )
data.head()
# Out:
#             Quantita Tipologia
# Calendario
# 2021-05-05      2.00     Spine
# 2021-05-21      3.25     Spine
# 2021-05-25    228.00     Spine
# 2021-05-26    181.80     Spine
# 2021-05-27    256.00     Spine

# %%
index = data.index

df_spine = data[data['Tipologia']=='Spine']
df_cocktail = data[data['Tipologia']=='Cocktail']
df_burger = data[data['Tipologia']=='Burger']
df_fritti = data[data['Tipologia']=='Fritti']
df_bar = data[data['Tipologia']=='Bar']

# %%
### ZOOM Plotly

import plotly.graph_objects as go

fig = go.Figure()

#Spine 
fig.add_trace(go.Scatter(x = index, 
                         y = df_spine['Quantita'],
                         mode = "lines",
                         name = "Spine",
                         line_color='#0000FF',
                         ))
##############################################################
#Cocktail 
fig.add_trace(go.Scatter(x = index, 
                         y = df_cocktail['Quantita'],
                         mode = "lines", 
                         name = "Cocktail",
                         line_color='#ff8c00',
                         ))
##############################################################
#Burger 
fig.add_trace(go.Scatter(x = index, 
                         y = df_burger['Quantita'],
                         mode = "lines", 
                         name = "Burger",
                         line_color='#FF00FF',
                         ))
##############################################################
#Fritti 
fig.add_trace(go.Scatter(x = index, 
                         y = df_fritti['Quantita'],
                         mode = "lines", 
                         name = "Fritti",
                         line_color='#00FF00',
                         ))
##############################################################
#Bar 
fig.add_trace(go.Scatter(x = index, 
                         y = df_bar['Quantita'],
                         mode = "lines", 
                         name = "Bar",
                         line_color='#FF0000',
                         ))
##############################################################
# adjust layout
fig.update_layout(title = "Vendite",
                  xaxis_title = "Data",
                  yaxis_title = "Quantità",
                  width = 1200,
                  height = 700,
                  )
####################################################################
# zoomming
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=15, label="15m", step="month", stepmode="backward"),
            dict(step="all")
        ])
    )
)

# %%
df_spine= df_spine.iloc[1: , :]

# %% [markdown]
# ### Correlazione tra Spine e Burger

# %%
df_spine[['Quantita']].corrwith(df_burger['Quantita'])
# Out:
# Quantita    0.360484
# dtype: float64

# %%
# !pip install meteostat -q
# Out:
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\frenz\appdata\local\programs\python\python38\lib\site-packages)

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2021, 5, 2)
end = datetime(2022, 11, 20) # fa una settimana di forecasting

cities = {'Forli':[44.233334,12.050000]}


# Create Point for Vancouver, BC
city = Point(list(cities.values())[0][0],list(cities.values())[0][1], 20)

# Get daily data for 2018
data = Daily(city, start, end)
data = data.fetch()
data['city'] = list(cities.keys())[0]

data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun  \
# time
# 2021-05-02  16.4  12.3  20.0   0.0   NaN  231.0  16.0   NaN  1010.1   NaN
# 2021-05-03  14.7  10.4  19.0   0.1   NaN  272.0   7.7   NaN  1018.7   NaN
# 2021-05-04  15.9   9.4  22.0   0.0   NaN  206.0   8.8   NaN  1015.7   NaN
# 2021-05-05  17.0  11.6  21.0   0.0   NaN  227.0  16.8   NaN  1008.6   NaN
# 2021-05-06  18.0  12.9  22.0   0.0   NaN  232.0  19.5   NaN  1010.3   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2022-11-16   9.9   7.0  12.0   8.8   NaN  286.0   7.2   NaN  1005.0   NaN
# 2022-11-17  10.2   7.0  13.0   0.0   NaN   41.0   3.4   NaN  1002.5   NaN
# 2022-11-18  11.0   7.0  15.0   0.0   NaN  300.0   7.6   NaN  1000.7   NaN
# 2022-11-19   9.4   7.0  11.0  21.5   NaN  274.0   8.0   NaN  1005.1   NaN
# 2022-11-20   9.4   3.0  14.0   2.7   NaN  292.0  10.6   NaN  1009.9   NaN
#
#              city
# time
# 2021-05-02  Forli
# 2021-05-03  Forli
# ...
